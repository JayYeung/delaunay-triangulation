# %%
import random
n = 1_000_000

with open('tests/bad.node', 'w') as file:
    file.write(f'{n} 2 0 0 \n')
    for i in range(1, n + 1):
        x, y = random.randint(1, 200), random.randint(1, 1_000_000_000_000)
        file.write(f'{i} {x} {y} \n')
